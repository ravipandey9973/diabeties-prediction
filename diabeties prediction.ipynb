# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the Dataset

# %%
df=pd.read_csv("diabetes.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.sample()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 697            0       99              0              0        0  25.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 697                     0.253   22        0

# %%
df.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 100            1      163             72              0        0  39.0
# 333           12      106             80              0        0  23.6
# 515            3      163             70             18      105  31.6
# 595            0      188             82             14      185  32.0
# 416            1       97             68             21        0  27.2
# 328            2      102             86             36      120  45.5
# 445            0      180             78             63       14  59.4
# 467            0       97             64             36      100  36.8
# 695            7      142             90             24      480  30.4
# 469            6      154             78             41      140  46.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 100                     1.222   33        1
# 333                     0.137   44        0
# 515                     0.268   28        1
# 595                     0.682   22        1
# 416                     1.095   22        0
# 328                     0.127   23        1
# 445                     2.420   25        1
# 467                     0.600   25        0
# 695                     0.128   43        1
# 469                     0.571   27        0

# %%
df.shape
# Out:
# (768, 9)

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# data cleaning
df.shape
# Out:
# (768, 9)

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (768, 9)

# %%
# same shape before after drop means there is not dublicates

# %%
# check null values
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# means there not missing values

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# # check the no. of zero values in dataset

# %%
print('No. of zero values in Glucose',df[df['Glucose']==0].shape[0])
# Out:
# No. of zero values in Glucose 5

# %%
print('No. of zero values in BloodPressure',df[df['BloodPressure']==0].shape[0])
# Out:
# No. of zero values in BloodPressure 35

# %%
print('No. of zero values in SkinThickness',df[df['SkinThickness']==0].shape[0])
# Out:
# No. of zero values in SkinThickness 227

# %%
print('No. of zero values in Insulin',df[df['Insulin']==0].shape[0])
# Out:
# No. of zero values in Insulin 374

# %%
print('No. of zero values in BMI',df[df['BMI']==0].shape[0])
# Out:
# No. of zero values in BMI 11

# %% [markdown]
# # Replace no.of zero values with mean of the columns

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
print('No. of zero values in Glucose',df[df['Glucose']==0].shape[0])
# Out:
# No. of zero values in Glucose 0

# %%
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())
print('No. of zero values in BloodPressure',df[df['BloodPressure']==0].shape[0])
# Out:
# No. of zero values in BloodPressure 0

# %%
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())
print('No. of zero values in SkinThickness',df[df['SkinThickness']==0].shape[0])
# Out:
# No. of zero values in SkinThickness 0

# %%
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].mean())
print('No. of zero values in Insulin',df[df['Insulin']==0].shape[0])
# Out:
# No. of zero values in Insulin 0

# %%
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())
print('No. of zero values in BMI',df[df['BMI']==0].shape[0])
# Out:
# No. of zero values in BMI 0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052   72.254807      72.254807      26.606479  118.660163
# std       3.369578   12.115932      12.115932       9.631241   93.080358
# min       0.000000   24.000000      24.000000       7.000000   14.000000
# 25%       1.000000   64.000000      64.000000      20.536458   79.799479
# 50%       3.000000   72.000000      72.000000      23.000000   79.799479
# 75%       6.000000   80.000000      80.000000      32.000000  127.250000
# max      17.000000  122.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# # Data Visualisation

# %%
f,ax=plt.subplots(1,2,figsize=(10,5))
df['Outcome'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Outcome')
ax[0].set_ylabel('')
sns.countplot('Outcome',data=df,ax=ax[1])
ax[1].set_title('outcome')
N,P=df['Outcome'].value_counts()
print('Negative (0):',N)
print('Positive (1):',P)
plt.grid()
plt.show()
# Out:
# Negative (0): 500
# Positive (1): 268

# %%
# Histograms
df.hist(bins=10,figsize=(10,10))
plt.show()

# %%
# Scatter plot
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize=(20,20));

# %%
# Pairplot
sns.pairplot(data=df,hue='Outcome')
plt.show()

# %% [markdown]
# # Analyzing relationships between variables

# %%
import seaborn as sns
corrnat=df.corr()
top_corr_features=corrnat.index
plt.figure(figsize=(10,10))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# # Split the data frame into X & Y

# %%
target_name='Outcome'
y=df[target_name]
x=df.drop(target_name,axis=1)

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6     72.0           72.0      35.000000   79.799479  33.6
# 1            1     66.0           66.0      29.000000   79.799479  26.6
# 2            8     64.0           64.0      20.536458   79.799479  23.3
# 3            1     66.0           66.0      23.000000   94.000000  28.1
# 4            0     40.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# # Apply Feature Scalling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x)
SSX=scaler.transform(x)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(SSX,y,test_size=0.2,random_state=7)

# %%
X_train.shape,y_train.shape
# Out:
# ((614, 8), (614,))

# %%
X_test.shape,y_test.shape
# Out:
# ((154, 8), (154,))

# %% [markdown]
# # Build the Classification Algorithms

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(solver='liblinear',multi_class='ovr')
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %%
# KNeighborClassifier(KNN)
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Naive-Bayes Classifier
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
# Support vector machine(svm)
from sklearn.svm import SVC
sv=SVC()
sv.fit(X_train,y_train)
# Out:
# SVC()

# %%
# Decision tree
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(criterion='entropy')
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %% [markdown]
# # Making Prediction

# %%
X_test.shape
# Out:
# (154, 8)

# %%
# making prediction on test dataset by logistic Regression
lr_pred=lr.predict(X_test)

# %%
lr_pred.shape
# Out:
# (154,)

# %%
# making prediction on test dataset by KNN
knn_pred=knn.predict(X_test)

# %%
# making prediction on test dataset by Naivie Bayes
nb_pred=nb.predict(X_test)

# %%
# making prediction on test dataset by svm
sv_pred=sv.predict(X_test)

# %%
# making prediction on test dataset by Decsion tree
dt_pred=dt.predict(X_test)

# %%
# making prediction on test dataset by Random Forest
rf_pred=rf.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %%
# Train score & Test score of Logistic Regression
from sklearn.metrics import accuracy_score
print("Train Accuracy of Logistic Regression",lr.score(X_train,y_train)*100)
print("Accuracy (Test) score of Logistic Regression",lr.score(X_test,y_test)*100)
print("Accuracy (Test) score of Logistic Regression",accuracy_score(y_test,lr_pred)*100)
# Out:
# Train Accuracy of Logistic Regression 71.00977198697068
# Accuracy (Test) score of Logistic Regression 72.07792207792207
# Accuracy (Test) score of Logistic Regression 72.07792207792207

# %%
# Train score & Test score of KNN
from sklearn.metrics import accuracy_score
print("Train Accuracy of KNN",knn.score(X_train,y_train)*100)
print("Accuracy (Test) score of KNN",knn.score(X_test,y_test)*100)
print("Accuracy  score of KNN",accuracy_score(y_test,knn_pred)*100)
# Out:
# Train Accuracy of KNN 77.68729641693811
# Accuracy (Test) score of KNN 69.48051948051948
# Accuracy  score of KNN 69.48051948051948

# %%
# Train score & Test score of Naive-Bayes
from sklearn.metrics import accuracy_score
print("Train Accuracy of Naive-Bayes",nb.score(X_train,y_train)*100)
print("Accuracy (Test) score of Naive-Bayes",nb.score(X_test,y_test)*100)
print("Accuracy  score of Naive-Bayes",accuracy_score(y_test,nb_pred)*100)
# Out:
# Train Accuracy of Naive-Bayes 69.38110749185668
# Accuracy (Test) score of Naive-Bayes 70.12987012987013
# Accuracy  score of Naive-Bayes 70.12987012987013

# %%
# Train score & Test score of svm
from sklearn.metrics import accuracy_score
print("Train Accuracy of svm",sv.score(X_train,y_train)*100)
print("Accuracy (Test) score of svm",sv.score(X_test,y_test)*100)
print("Accuracy  score of svm",accuracy_score(y_test,sv_pred)*100)
# Out:
# Train Accuracy of svm 75.8957654723127
# Accuracy (Test) score of svm 68.18181818181817
# Accuracy  score of svm 68.18181818181817

# %%
# Train score & Test score of Decesion Tree
from sklearn.metrics import accuracy_score
print("Train Accuracy of Decesion Tree",dt.score(X_train,y_train)*100)
print("Accuracy (Test) score of Decesion Tree",dt.score(X_test,y_test)*100)
print("Accuracy  score of Decesion Tree",accuracy_score(y_test,dt_pred)*100)
# Out:
# Train Accuracy of Decesion Tree 100.0
# Accuracy (Test) score of Decesion Tree 63.63636363636363
# Accuracy  score of Decesion Tree 63.63636363636363

# %%
# Train score & Test score of Random Forest
from sklearn.metrics import accuracy_score
print("Train Accuracy of Random Forest ",rf.score(X_train,y_train)*100)
print("Accuracy (Test) score of Random Forest",rf.score(X_test,y_test)*100)
print("Accuracy  score of Random Forest",accuracy_score(y_test,rf_pred)*100)
# Out:
# Train Accuracy of Random Forest  100.0
# Accuracy (Test) score of Random Forest 72.07792207792207
# Accuracy  score of Random Forest 72.07792207792207

# %%
# confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
# confusion Matrix Logistic Regression
cm=confusion_matrix(y_test,lr_pred)
cm
# Out:
# array([[87, 10],
#        [33, 24]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,lr_pred),annot=True,fmt="d")
# Out:
# <AxesSubplot:>

# %%
print('classification Report of Logistic Regression:\n',classification_report(y_test,lr_pred,digits=4))
# Out:
# classification Report of Logistic Regression:
#                precision    recall  f1-score   support
#
#            0     0.7250    0.8969    0.8018        97
#            1     0.7059    0.4211    0.5275        57
#
#     accuracy                         0.7208       154
#    macro avg     0.7154    0.6590    0.6647       154
# weighted avg     0.7179    0.7208    0.7003       154

# %%
TN=cm[0,0]
FP= cm[0,1]
FN=cm[1,0]
TP=cm[1,1]

# %%
TN,FP,FN,TP
# Out:
# (87, 10, 33, 24)

# %%
# making the confusion matrix of logistic Regression
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve
cm=confusion_matrix(y_test,lr_pred)

print('TN - True Negative {}'.format(cm[0,0]))
print('FP - True Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))
print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))*100))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))
# Out:
# TN - True Negative 87
# FP - True Positive 10
# FN - False Negative 33
# TP - True Positive 24
# Accuracy Rate: 72.07792207792207
# Misclassification Rate: 27.92207792207792

# %%
import matplotlib.pyplot as plt 
plt.clf()
plt.imshow(cm,interpolation='nearest',cmap=plt.cm.Wistia)
classNames=['0','1']
plt.title('confusion matrix of Logistic Regression')
plt.ylabel('Actual(true) values')
plt.xlabel('Predicted values')
tick_marks=np.arange(len(classNames))
plt.xticks(tick_marks,classNames,rotation=45)
plt.yticks(tick_marks,classNames)
s=[['TN','FP'],['FN','TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i,str(s[i][j])+" + "+str(cm[i][j]))
plt.show()

# %%
pd.crosstab(y_test,lr_pred,margins=False)
# Out:
# col_0     0   1
# Outcome
# 0        87  10
# 1        33  24

# %%
pd.crosstab(y_test,lr_pred,margins=True)
# Out:
# col_0      0   1  All
# Outcome
# 0         87  10   97
# 1         33  24   57
# All      120  34  154

# %%
pd.crosstab(y_test,lr_pred,rownames=['Actual values'],colnames=['Predicted values'],margins=True)
# Out:
# Predicted values    0   1  All
# Actual values
# 0                  87  10   97
# 1                  33  24   57
# All               120  34  154

# %% [markdown]
# # PRECISION (PPV-Positive Predictive Value)

# %%
TP,FP
# Out:
# (24, 10)

# %%
24/(24+10)
# Out:
# 0.7058823529411765

# %%
Precision=TP/(TP+FP)
Precision
# Out:
# 0.7058823529411765

# %%
# Print precision score
precision_score=TP/float(TP+FP)*100
print('precision score:{0:0.4f}'.format(precision_score))
# Out:
# precision score:70.5882

# %%
from sklearn.metrics import precision_score
print("precision score is:",precision_score(y_test,lr_pred)*100)
print("Mircro Average precision score is:",precision_score(y_test,lr_pred,average='micro')*100)
print("Macro Average precision score is:",precision_score(y_test,lr_pred,average='macro')*100)
print("Weighted Average precision score is:",precision_score(y_test,lr_pred,average='weighted')*100)
print("precision score on Non weighted score is:",precision_score(y_test,lr_pred,average=None)*100)
# Out:
# precision score is: 70.58823529411765
# Mircro Average precision score is: 72.07792207792207
# Macro Average precision score is: 71.54411764705883
# Weighted Average precision score is: 71.7923987776929
# precision score on Non weighted score is: [72.5        70.58823529]

# %%
print('classification Report of Logistic Regression: \n',classification_report(y_test,lr_pred,digits=4))
# Out:
# classification Report of Logistic Regression:
#                precision    recall  f1-score   support
#
#            0     0.7250    0.8969    0.8018        97
#            1     0.7059    0.4211    0.5275        57
#
#     accuracy                         0.7208       154
#    macro avg     0.7154    0.6590    0.6647       154
# weighted avg     0.7179    0.7208    0.7003       154

# %% [markdown]
# # Recall (True Positive Rate (TPR))

# %%
recall_score=TP/float(TP+FN)*100
print('recall_score',recall_score)
# Out:
# recall_score 42.10526315789473

# %%
TP,FN
# Out:
# (24, 33)

# %%
33/(33+24)
# Out:
# 0.5789473684210527

# %%
from  sklearn.metrics import recall_score
print('Recall or sensitivity_score:',recall_score(y_test,lr_pred)*100)
# Out:
# Recall or sensitivity_score: 42.10526315789473

# %%
print("Mircro Average Recall Score is:",recall_score(y_test,lr_pred,average='micro')*100)
print("Marcro Average Recall Score is:",recall_score(y_test,lr_pred,average='macro')*100)
print("Weighted Average Recall Score is:",recall_score(y_test,lr_pred,average='weighted')*100)
print("Recall Score  on Non weighted score is:",recall_score(y_test,lr_pred,average=None)*100)
# Out:
# Mircro Average Recall Score is: 72.07792207792207
# Marcro Average Recall Score is: 65.89799240368963
# Weighted Average Recall Score is: 72.07792207792207
# Recall Score  on Non weighted score is: [89.69072165 42.10526316]

# %%
print('Classification Report of Logistic Regression: \n',classification_report(y_test,lr_pred,digits=4))
# Out:
# Classification Report of Logistic Regression:
#                precision    recall  f1-score   support
#
#            0     0.7250    0.8969    0.8018        97
#            1     0.7059    0.4211    0.5275        57
#
#     accuracy                         0.7208       154
#    macro avg     0.7154    0.6590    0.6647       154
# weighted avg     0.7179    0.7208    0.7003       154

# %% [markdown]
# # False Positive Rate (FPR)

# %%
FPR=FP/float(FP+TN)*100
print('False Positive Rate : {0:0.4f}'.format(FPR))
# Out:
# False Positive Rate : 10.3093

# %%
FP,TN
# Out:
# (10, 87)

# %%
11/(11+86)
# Out:
# 0.1134020618556701

# %% [markdown]
# # Specificity

# %%
specificity=TN/(TN+FP)*100
print('specificity: {0:0.4f}'.format(specificity))
# Out:
# specificity: 89.6907

# %% [markdown]
# # F1-Score

# %%
from sklearn.metrics import f1_score
print('f1_score of macro :',f1_score(y_test,lr_pred)*100)
# Out:
# f1_score of macro : 52.74725274725274

# %%
print("Mircro Average F1_Score is :",f1_score(y_test,lr_pred,average='micro')*100)
print("Marcro Average F1_Score is :",f1_score(y_test,lr_pred,average='macro')*100)
print("weighted Average F1_Score is :",f1_score(y_test,lr_pred,average='weighted')*100)
print("F1_Score on Non weighted score is :",f1_score(y_test,lr_pred,average=None)*100)
# Out:
# Mircro Average F1_Score is : 72.07792207792207
# Marcro Average F1_Score is : 66.46579227224387
# weighted Average F1_Score is : 70.02904929172209
# F1_Score on Non weighted score is : [80.1843318  52.74725275]

# %% [markdown]
# # Classification Report of Logistic Regression

# %%
from sklearn.metrics import classification_report
print('classification Report of Logistic Regression : \n',classification_report(y_test,lr_pred,digits=4))
# Out:
# classification Report of Logistic Regression :
#                precision    recall  f1-score   support
#
#            0     0.7250    0.8969    0.8018        97
#            1     0.7059    0.4211    0.5275        57
#
#     accuracy                         0.7208       154
#    macro avg     0.7154    0.6590    0.6647       154
# weighted avg     0.7179    0.7208    0.7003       154

# %% [markdown]
# # Roc Curve & ROC AUC

# %%
# Area Under Curve
auc=roc_auc_score(y_test,lr_pred)
print("ROC AUC SCORE of Logistic Regression is",auc)
# Out:
# ROC AUC SCORE of Logistic Regression is 0.6589799240368963

# %%
fpr,tpr,thresholds=roc_curve(y_test,lr_pred)
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC curve (area=%0.2f)'% auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receive Operating characteristics (ROC) Curve of Logistic Regression')
plt.legend()
plt.grid()
plt.show()

# %%
# confusion matrix of KNN
sns.heatmap(confusion_matrix(y_test,knn_pred),annot=True,fmt="d")
# Out:
# <AxesSubplot:>

# %%
# making the confusion matrix ofKNN
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve
cm=confusion_matrix(y_test,knn_pred)

print('TN - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))
print('Accuracy Rate : {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))*100))
print('Misclassification Rate : {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))
# Out:
# TN - True Negative 81
# FP - False Positive 16
# FN - False Negative 31
# TP - True Positive 26
# Accuracy Rate : 69.48051948051948
# Misclassification Rate : 30.519480519480517

# %% [markdown]
# # Area Under of KNN

# %%
# AREA UNDER CURVE
auc=roc_auc_score(y_test,knn_pred)
print("ROC AUC SCORE of KNN is",auc)
# Out:
# ROC AUC SCORE of KNN is 0.6455959486344729

# %%
fpr,tpr,thresholds=roc_curve(y_test,knn_pred)
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC curve (area=%0.2f)'% auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receive Operating characteristics (ROC) Curve of KNN')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # confusion matrix of Naive Bayes

# %%
# making the confusion matrix of Naive Bayes
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve
cm=confusion_matrix(y_test,nb_pred)

print('TN - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))
print('Accuracy Rate : {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))*100))
print('Misclassification Rate : {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))
# Out:
# TN - True Negative 78
# FP - False Positive 19
# FN - False Negative 27
# TP - True Positive 30
# Accuracy Rate : 70.12987012987013
# Misclassification Rate : 29.87012987012987

# %%
sns.heatmap(confusion_matrix(y_test,nb_pred),annot=True,fmt="d")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Classification Report of * Naive Bayes

# %%
print('classification Report of Naive Bayes : \n',classification_report(y_test,nb_pred,digits=4))
# Out:
# classification Report of Naive Bayes :
#                precision    recall  f1-score   support
#
#            0     0.7429    0.8041    0.7723        97
#            1     0.6122    0.5263    0.5660        57
#
#     accuracy                         0.7013       154
#    macro avg     0.6776    0.6652    0.6692       154
# weighted avg     0.6945    0.7013    0.6959       154

# %%
# Roc AUC score of Naive Bayes
# are under curve
auc=roc_auc_score(y_test,nb_pred)
print("ROC AUC SCORE of Naive Bayes is",auc)
# Out:
# ROC AUC SCORE of Naive Bayes is 0.6652197504069453

# %%
fpr,tpr,thresholds=roc_curve(y_test,nb_pred)
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC curve (area=%0.2f)'% auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receive Operating characteristics (ROC) Curve of Naive Bayes')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # confusion Matrix of SVM

# %%
sns.heatmap(confusion_matrix(y_test,sv_pred),annot=True,fmt="d")
# Out:
# <AxesSubplot:>

# %%
# making the confusion matrix of SVM
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve
cm=confusion_matrix(y_test,sv_pred)

print('TN - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))
print('Accuracy Rate : {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))*100))
print('Misclassification Rate : {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))
# Out:
# TN - True Negative 82
# FP - False Positive 15
# FN - False Negative 34
# TP - True Positive 23
# Accuracy Rate : 68.18181818181817
# Misclassification Rate : 31.818181818181817

# %% [markdown]
# # Classification Report of SVM

# %%
print('classification Report of SVM : \n',classification_report(y_test,sv_pred,digits=4))
# Out:
# classification Report of SVM :
#                precision    recall  f1-score   support
#
#            0     0.7069    0.8454    0.7700        97
#            1     0.6053    0.4035    0.4842        57
#
#     accuracy                         0.6818       154
#    macro avg     0.6561    0.6244    0.6271       154
# weighted avg     0.6693    0.6818    0.6642       154

# %% [raw]
# # Roc AUC of SVM

# %%
auc=round(roc_auc_score(y_test,sv_pred)*100,2)
print("ROC AUC SCORE of SVC is",auc)
# Out:
# ROC AUC SCORE of SVC is 62.44

# %%
fpr,tpr,thresholds=roc_curve(y_test,sv_pred)
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC curve (area=%0.2f)'% auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receive Operating characteristics (ROC) Curve of SVM')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Confusion matrix of Decision Tree

# %%
sns.heatmap(confusion_matrix(y_test,dt_pred),annot=True,fmt="d")
# Out:
# <AxesSubplot:>

# %%
# making the confusion matrix of SVM
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve
cm=confusion_matrix(y_test,dt_pred)

print('TN - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))
print('Accuracy Rate : {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))*100))
print('Misclassification Rate : {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))
# Out:
# TN - True Negative 71
# FP - False Positive 26
# FN - False Negative 30
# TP - True Positive 27
# Accuracy Rate : 63.63636363636363
# Misclassification Rate : 36.36363636363637

# %%
print('classification Report of SVM : \n',classification_report(y_test,dt_pred,digits=4))
# Out:
# classification Report of SVM :
#                precision    recall  f1-score   support
#
#            0     0.7030    0.7320    0.7172        97
#            1     0.5094    0.4737    0.4909        57
#
#     accuracy                         0.6364       154
#    macro avg     0.6062    0.6028    0.6040       154
# weighted avg     0.6313    0.6364    0.6334       154

# %%
auc=round(roc_auc_score(y_test,dt_pred)*100,2)
print("ROC AUC SCORE of Decision Tree is",auc)
# Out:
# ROC AUC SCORE of Decision Tree is 60.28

# %%
fpr,tpr,thresholds=roc_curve(y_test,dt_pred)
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC curve (area=%0.2f)'% auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receive Operating characteristics (ROC) Curve of Decision Tree')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Confusion Matrix of Random Forest

# %%
sns.heatmap(confusion_matrix(y_test,rf_pred),annot=True,fmt="d")
# Out:
# <AxesSubplot:>

# %%
# making the confusion matrix of SVM
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve
cm=confusion_matrix(y_test,rf_pred)

print('TN - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))
print('Accuracy Rate : {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))*100))
print('Misclassification Rate : {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))
# Out:
# TN - True Negative 83
# FP - False Positive 14
# FN - False Negative 29
# TP - True Positive 28
# Accuracy Rate : 72.07792207792207
# Misclassification Rate : 27.92207792207792

# %%
print('classification Report of SVM : \n',classification_report(y_test,rf_pred,digits=4))
# Out:
# classification Report of SVM :
#                precision    recall  f1-score   support
#
#            0     0.7411    0.8557    0.7943        97
#            1     0.6667    0.4912    0.5657        57
#
#     accuracy                         0.7208       154
#    macro avg     0.7039    0.6734    0.6800       154
# weighted avg     0.7135    0.7208    0.7096       154

# %%
auc=round(roc_auc_score(y_test,rf_pred)*100,2)
print("ROC AUC SCORE of Random Forest is",auc)
# Out:
# ROC AUC SCORE of Random Forest is 67.34

# %%
fpr,tpr,thresholds=roc_curve(y_test,rf_pred)
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC curve (area=%0.2f)'% auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receive Operating characteristics (ROC) Curve of Random Forest')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # END
